# %%
dbutils.widgets.removeAll()

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType
from pyspark.sql.functions import current_timestamp, to_timestamp, concat, col, lit

# %%
dbutils.widgets.text("container", "raw")
dbutils.widgets.text("catalogo", "catalog_au")
dbutils.widgets.text("esquema", "bronze")
dbutils.widgets.text("storageName", "adlsproysmartdata01")

# %%
container = dbutils.widgets.get("container")
catalogo = dbutils.widgets.get("catalogo")
esquema = dbutils.widgets.get("esquema")
storageName = dbutils.widgets.get("storageName")

ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/SMS_Plataforma_Antigua.csv"

# %%
sms_antiguo_schema = StructType(fields=[
    StructField("producto", StringType(), True),
    StructField("fecha_envio", DateType(), True),
    StructField("usuarioSAC", StringType(), True),
    StructField("numero", StringType(), True),
    StructField("control", StringType(), True)
])

# %%
df_sms_antiguo = spark.read\
.option('header', True)\
.schema(sms_antiguo_schema)\
.csv(ruta)

# %%
df_sms_antiguo.display()
sms_antiguo_final_df.display()

# %%
sms_antiguo_final_df = df_sms_antiguo.select(
    col("producto"),
    col("fecha_envio"),
    col("usuarioSAC"),
    col("numero"),
    col("control")
).withColumn("ingestion_date", current_timestamp())

# %%
sms_antiguo_final_df.write \
    .mode("overwrite") \
    .insertInto(f"{catalogo}.{esquema}.sms_antiguo")

# %%
# %sql
SELECT * FROM catalog_au.bronze.sms_antiguo
